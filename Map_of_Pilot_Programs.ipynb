# %%
# import libraries
import folium

# make the map of Greece
m = folium.Map(location=[39.338820,22.581326], tiles="Mapbox Bright", zoom_start=6)

html_athens="""
<!DOCTYPE html>
<html>
<head>
    <style>
    table {
      font-family: arial, sans-serif;
      border-collapse: collapse;
      width: 100%;
    }

    td, th {
      border: 1px solid #dddddd;
      text-align: left;
      padding: 8px;
    }

    tr:nth-child(even) {
      background-color: #dddddd;
    }
    tr:nth-child(even) {
    background-color: #eee;
    }
    tr:nth-child(odd) {
    background-color: #fff;
    }
    th {
    background-color: #848484;
    color: white;
    }
    </style>
</head>
<body>
    <h5>Pilot <code> Athens</code></h5>
    <table>
      <tr>
        <th># Total Patients</th>
        <th># Consistent Patients</th>
      </tr>
      <tr>
        <td>34</td>
        <td>2</td>
      </tr>
    </table> </br>
    <table>
      <tr>
        <th>Sex</th>
        <th># Total Patients</th>
        <th># Consistent Patients</th>
      </tr>
      <tr>
        <td bgcolor="#eee">Men</td>
        <td bgcolor="#fff">14</td>
        <td bgcolor="#fff">1</td>
      </tr>
      <tr>
        <td bgcolor="#eee">Women</td>
        <td bgcolor="#fff">20</td>
        <td bgcolor="#fff">1</td>
      </tr>
    </table> </br>
     <table>
      <tr>
        <th>Age</th>
        <th># Total Patients</th>
        <th># Consistent Patients</th>
      </tr>
      <tr>
        <td bgcolor="#eee">< 65</td>
        <td bgcolor="#fff">14</td>
        <td bgcolor="#fff">0</td>
      </tr>
      <tr>
        <td bgcolor="#eee">&ge; 65</td>
        <td bgcolor="#fff">20</td>
        <td bgcolor="#fff">2</td>
      </tr>
    </table>
</body>
</html>
"""
html_ath = folium.Html(html_athens, script =True, width=350, height=335)
popup_ath = folium.Popup(html_ath, max_width=2650)

html_larisa="""
<!DOCTYPE html>
<html>
<head>
    <style>
    table {
      font-family: arial, sans-serif;
      border-collapse: collapse;
      width: 100%;
    }

    td, th {
      border: 1px solid #dddddd;
      text-align: left;
      padding: 8px;
    }
    tr:nth-child(even) {
      background-color: #dddddd;
    }
    tr:nth-child(even) {
    background-color: #eee;
    }
    tr:nth-child(odd) {
    background-color: #fff;
    }
    th {
    background-color: #848484;
    color: white;
    }
    </style>
</head>
<body>
    <h5>Pilot <code> Larisa</code></h5>
    <table>
      <tr>
        <th colspan="3"># Patients</th>
        <th colspan="3"># Consistent Patients</th>
      </tr>
      <tr>
        <td>Total</td>
        <td>Active</td>
        <td>Inactive</td>
        <td>Total</td>
        <td>Active</td>
        <td>Inactive</td>
      </tr>
      <tr>
        <td>34</td>
        <td>26</td>
        <td>8</td>
        <td>13</td>
        <td>13</td>
        <td>1</td>
      </tr>
    </table> </br>
    <table>
      <tr>
        <th>Sex</th>
        <th># Total Patients</th>
        <th># Consistent Patients</th>
      </tr>
      <tr>
        <td bgcolor="#eee">Men</td>
        <td bgcolor="#fff">27</td>
        <td bgcolor="#fff">11</td>
      </tr>
      <tr>
        <td bgcolor="#eee">Women</td>
        <td bgcolor="#fff">7</td>
        <td bgcolor="#fff">2</td>
      </tr>
    </table> </br>
     <table>
      <tr>
        <th>Age</th>
        <th># Total Patients</th>
        <th># Consistent Patients</th>
      </tr>
      <tr>
        <td bgcolor="#eee">< 65</td>
        <td bgcolor="#fff">16</td>
        <td bgcolor="#fff">5</td>
      </tr>
      <tr>
        <td bgcolor="#eee">&ge; 65</td>
        <td bgcolor="#fff">18</td>
        <td bgcolor="#fff">8</td>
      </tr>
    </table>
</body>
</html>
"""
html_larisa = folium.Html(html_larisa, script =True, width=350, height=365)
popup_larisa = folium.Popup(html_larisa, max_width=2650)

html_thessaloniki="""
<!DOCTYPE html>
<html>
<head>
    <style>
    table {
      font-family: arial, sans-serif;
      border-collapse: collapse;
      width: 100%;
    }

    td, th {
      border: 1px solid #dddddd;
      text-align: left;
      padding: 8px;
    }
    tr:nth-child(even) {
      background-color: #dddddd;
    }
    tr:nth-child(even) {
    background-color: #eee;
    }
    tr:nth-child(odd) {
    background-color: #fff;
    }
    th {
    background-color: #848484;
    color: white;
    }
    </style>
</head>
<body>
    <h5>Pilot <code> Thessaloniki</code></h5>
    <table>
      <tr>
        <th colspan="3"># Patients</th>
        <th colspan="3"># Consistent Patients</th>
      </tr>
      <tr>
        <td>Total</td>
        <td>Active</td>
        <td>Inactive</td>
        <td>Total</td>
        <td>Active</td>
        <td>Inactive</td>
      </tr>
      <tr>
        <td>7</td>
        <td>6</td>
        <td>1</td>
        <td>2</td>
        <td>2</td>
        <td>0</td>
      </tr>
    </table> </br>
    <table>
      <tr>
        <th>Sex</th>
        <th># Total Patients</th>
        <th># Consistent Patients</th>
      </tr>
      <tr>
        <td bgcolor="#eee">Men</td>
        <td bgcolor="#fff">7</td>
        <td bgcolor="#fff">2</td>
      </tr>
      <tr>
        <td bgcolor="#eee">Women</td>
        <td bgcolor="#fff">0</td>
        <td bgcolor="#fff">0</td>
      </tr>
    </table> </br>
     <table>
      <tr>
        <th>Age</th>
        <th># Total Patients</th>
        <th># Consistent Patients</th>
      </tr>
      <tr>
        <td bgcolor="#eee">< 65</td>
        <td bgcolor="#fff">2</td>
        <td bgcolor="#fff">0</td>
      </tr>
      <tr>
        <td bgcolor="#eee">&ge; 65</td>
        <td bgcolor="#fff">5</td>
        <td bgcolor="#fff">2</td>
      </tr>
    </table>
</body>
</html>
"""
html_thessaloniki = folium.Html(html_thessaloniki, script =True, width=350, height=365)
popup_thessaloniki = folium.Popup(html_thessaloniki, max_width=2650)

html_crete="""
<!DOCTYPE html>
<html>
<head>
    <style>
    table {
      font-family: arial, sans-serif;
      border-collapse: collapse;
      width: 100%;
    }

    td, th {
      border: 1px solid #dddddd;
      text-align: left;
      padding: 8px;
    }
    tr:nth-child(even) {
      background-color: #dddddd;
    }
    tr:nth-child(even) {
    background-color: #eee;
    }
    tr:nth-child(odd) {
    background-color: #fff;
    }
    th {
    background-color: #848484;
    color: white;
    }
    </style>
</head>
<body>
    <h5>Pilot <code> Crete</code></h5>
    <table>
      <tr>
        <th colspan="3"># Patients</th>
        <th colspan="3"># Consistent Patients</th>
      </tr>
      <tr>
        <td>Total</td>
        <td>Active</td>
        <td>Inactive</td>
        <td>Total</td>
        <td>Active</td>
        <td>Inactive</td>
      </tr>
      <tr>
        <td>8</td>
        <td>7</td>
        <td>1</td>
        <td>4</td>
        <td>4</td>
        <td>0</td>
      </tr>
    </table> </br>
    <table>
      <tr>
        <th>Sex</th>
        <th># Total Patients</th>
        <th># Consistent Patients</th>
      </tr>
      <tr>
        <td bgcolor="#eee">Men</td>
        <td bgcolor="#fff">8</td>
        <td bgcolor="#fff">4</td>
      </tr>
      <tr>
        <td bgcolor="#eee">Women</td>
        <td bgcolor="#fff">0</td>
        <td bgcolor="#fff">0</td>
      </tr>
    </table> </br>
     <table>
      <tr>
        <th>Age</th>
        <th># Total Patients</th>
        <th># Consistent Patients</th>
      </tr>
      <tr>
        <td bgcolor="#eee">< 65</td>
        <td bgcolor="#fff">3</td>
        <td bgcolor="#fff">1</td>
      </tr>
      <tr>
        <td bgcolor="#eee">&ge; 65</td>
        <td bgcolor="#fff">5</td>
        <td bgcolor="#fff">3</td>
      </tr>
    </table>
</body>
</html>
"""
html_crete = folium.Html(html_crete, script =True, width=350, height=365)
popup_crete = folium.Popup(html_crete, max_width=2650)

#Add markers on the map
folium.Marker(location = [37.985283, 23.725463], popup=popup_ath).add_to(m)
folium.Circle(location = [37.985283, 23.725463], radius='48000', color='crimson', fill=True, fill_color='crimson').add_to(m)
folium.Marker(location = [39.506768, 22.592760], popup=popup_larisa).add_to(m)
folium.Circle(location = [39.506768, 22.592760], radius='34000', color='crimson', fill=True, fill_color='crimson').add_to(m)
folium.Marker(location = [40.820756, 23.083325], popup=popup_thessaloniki).add_to(m)
folium.Circle(location = [40.820756, 23.083325], radius='12000', color='crimson', fill=True, fill_color='crimson').add_to(m)
folium.Marker(location = [35.328096, 25.150328], popup=popup_crete).add_to(m)
folium.Circle(location = [35.328096, 25.150328], radius='12000', color='crimson', fill=True, fill_color='crimson').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
